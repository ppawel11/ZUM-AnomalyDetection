# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_eval_data.csv")

# %%
sns.boxplot(df, x="dissimilarity", y="fscore", hue="grouping_algorithm")
plt.title(f"F-score on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="precision", hue="grouping_algorithm")
plt.title(f"precision on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="accuracy", hue="grouping_algorithm")
plt.title(f"accuracy on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="recall", hue="grouping_algorithm")
plt.title(f"recall on wine")
plt.show()

# %%
df[df["anomaly_drop_rates"] == 0.3].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 182  0.517241      1.000  0.826087
#                    LDCOF                 245  0.864865      1.000  0.937888
#                    naive                  56  0.351351      0.875  0.776398
#                    uCBLOF                119  0.864865      1.000  0.937888
# kmeans             CBLOF                 155  0.486486      0.750  0.763975
#                    LDCOF                 218  0.540541      1.000  0.788820
#                    naive                  29  0.513514      0.875  0.788820
#                    uCBLOF                 92  0.567568      1.000  0.826087
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.452381                   0.2
#                    LDCOF          0.761905                   0.2
#                    naive          0.309524                   0.2
#                    uCBLOF         0.761905                   0.2
# kmeans             CBLOF          0.428571                   0.2
#                    LDCOF          0.476190                   0.2
#                    naive          0.452381                   0.2
#                    uCBLOF         0.500000                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.3         NaN  23.0
#                    LDCOF                         0.3         NaN  23.0
#                    naive                         0.3         NaN  23.0
#                    uCBLOF                        0.3         NaN  23.0
# kmeans             CBLOF                         0.3         6.0   NaN
#                    LDCOF                         0.3         6.0   NaN
#                    naive                         0.3         6.0   NaN
#                    uCBLOF                        0.3         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN

# %%
df[df["anomaly_drop_rates"] == 0.5].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 185  0.545455   1.000000  0.865772
#                    LDCOF                 248  0.813559   1.000000  0.926174
#                    naive                  59  0.454545   0.857143  0.838926
#                    uCBLOF                122  0.915254   1.000000  0.966443
# kmeans             CBLOF                 158  0.500000   0.785714  0.852349
#                    LDCOF                 221  0.474576   1.000000  0.845638
#                    naive                  32  0.542373   0.857143  0.838926
#                    uCBLOF                 95  0.644068   1.000000  0.892617
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.433333                   0.2
#                    LDCOF          0.800000                   0.2
#                    naive          0.333333                   0.2
#                    uCBLOF         0.900000                   0.2
# kmeans             CBLOF          0.366667                   0.2
#                    LDCOF          0.466667                   0.2
#                    naive          0.533333                   0.2
#                    uCBLOF         0.633333                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.5         NaN  23.0
#                    LDCOF                         0.5         NaN  23.0
#                    naive                         0.5         NaN  23.0
#                    uCBLOF                        0.5         NaN  23.0
# kmeans             CBLOF                         0.5         6.0   NaN
#                    LDCOF                         0.5         6.0   NaN
#                    naive                         0.5         6.0   NaN
#                    uCBLOF                        0.5         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN

# %%
df[df["anomaly_drop_rates"] == 0.8].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 188  0.800000   0.833333  0.961832
#                    LDCOF                 251  0.800000   1.000000  0.961832
#                    naive                  62  0.666667   1.000000  0.954198
#                    uCBLOF                125  0.960000   1.000000  0.992366
# kmeans             CBLOF                 161  0.320000   0.333333  0.893130
#                    LDCOF                 224  0.666667   1.000000  0.954198
#                    naive                  35  0.666667   1.000000  0.954198
#                    uCBLOF                 98  0.800000   1.000000  0.961832
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.833333                   0.2
#                    LDCOF          1.000000                   0.2
#                    naive          0.666667                   0.2
#                    uCBLOF         1.000000                   0.2
# kmeans             CBLOF          0.416667                   0.2
#                    LDCOF          0.750000                   0.2
#                    naive          0.750000                   0.2
#                    uCBLOF         1.000000                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.8         NaN  23.0
#                    LDCOF                         0.8         NaN  23.0
#                    naive                         0.8         NaN  23.0
#                    uCBLOF                        0.8         NaN  23.0
# kmeans             CBLOF                         0.8         6.0   NaN
#                    LDCOF                         0.8         6.0   NaN
#                    naive                         0.8         6.0   NaN
#                    uCBLOF                        0.8         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN

# %%
df = pd.read_csv("breast_cancer_eval_data.csv")

# %%
sns.boxplot(df, x="dissimilarity", y="fscore", hue="grouping_algorithm")
plt.title(f"F-score on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="precision", hue="grouping_algorithm")
plt.title(f"precision on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="accuracy", hue="grouping_algorithm")
plt.title(f"accuracy on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="recall", hue="grouping_algorithm")
plt.title(f"recall on breast cancer")
plt.show()

# %%
df[df["anomaly_drop_rates"] == 0.3].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 182  0.841379   1.000000  0.924837
#                    LDCOF                 245  0.841379   1.000000  0.924837
#                    naive                  56  0.841379   1.000000  0.924837
#                    uCBLOF                119  0.841379   1.000000  0.924837
# kmeans             CBLOF                 155  0.455172   0.540984  0.741830
#                    LDCOF                 218  0.841379   1.000000  0.924837
#                    naive                  29  0.765517   0.934426  0.888889
#                    uCBLOF                 92  0.841379   1.000000  0.924837
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.726190                   0.2
#                    LDCOF          0.726190                   0.2
#                    naive          0.726190                   0.2
#                    uCBLOF         0.726190                   0.2
# kmeans             CBLOF          0.392857                   0.2
#                    LDCOF          0.726190                   0.2
#                    naive          0.660714                   0.2
#                    uCBLOF         0.726190                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.3         NaN  23.0
#                    LDCOF                         0.3         NaN  23.0
#                    naive                         0.3         NaN  23.0
#                    uCBLOF                        0.3         NaN  23.0
# kmeans             CBLOF                         0.3         6.0   NaN
#                    LDCOF                         0.3         6.0   NaN
#                    naive                         0.3         6.0   NaN
#                    uCBLOF                        0.3         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN

# %%
df[df["anomaly_drop_rates"] == 0.5].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 185  0.913793   1.000000  0.964539
#                    LDCOF                 248  0.922414   1.000000  0.968085
#                    naive                  59  0.931034   1.000000  0.971631
#                    uCBLOF                122  0.922414   1.000000  0.968085
# kmeans             CBLOF                 158  0.159091   0.250000  0.755319
#                    LDCOF                 221  0.913793   1.000000  0.964539
#                    naive                  32  0.801724   0.892857  0.918440
#                    uCBLOF                 95  0.913793   1.000000  0.964539
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.883333                   0.2
#                    LDCOF          0.891667                   0.2
#                    naive          0.900000                   0.2
#                    uCBLOF         0.891667                   0.2
# kmeans             CBLOF          0.141667                   0.2
#                    LDCOF          0.883333                   0.2
#                    naive          0.775000                   0.2
#                    uCBLOF         0.883333                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.5         NaN  23.0
#                    LDCOF                         0.5         NaN  23.0
#                    naive                         0.5         NaN  23.0
#                    uCBLOF                        0.5         NaN  23.0
# kmeans             CBLOF                         0.5         6.0   NaN
#                    LDCOF                         0.5         6.0   NaN
#                    naive                         0.5         6.0   NaN
#                    uCBLOF                        0.5         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN

# %%
df[df["anomaly_drop_rates"] == 0.8].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 188  0.907216   1.000000  0.981707
#                    LDCOF                 251  0.886598   1.000000  0.977642
#                    naive                  62  0.907216   1.000000  0.981707
#                    uCBLOF                125  0.886598   1.000000  0.977642
# kmeans             CBLOF                 161  0.232877   0.173469  0.857724
#                    LDCOF                 224  0.886598   1.000000  0.977642
#                    naive                  35  0.742268   0.791667  0.949187
#                    uCBLOF                 98  0.886598   1.000000  0.977642
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          1.000000                   0.2
#                    LDCOF          1.000000                   0.2
#                    naive          1.000000                   0.2
#                    uCBLOF         1.000000                   0.2
# kmeans             CBLOF          0.354167                   0.2
#                    LDCOF          1.000000                   0.2
#                    naive          1.000000                   0.2
#                    uCBLOF         1.000000                   0.2
#
#                                   anomaly_drop_rates  n_clusters   eps  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                         0.8         NaN  23.0
#                    LDCOF                         0.8         NaN  23.0
#                    naive                         0.8         NaN  23.0
#                    uCBLOF                        0.8         NaN  23.0
# kmeans             CBLOF                         0.8         6.0   NaN
#                    LDCOF                         0.8         6.0   NaN
#                    naive                         0.8         6.0   NaN
#                    uCBLOF                        0.8         6.0   NaN
#
#                                   min_samples
# grouping_algorithm dissimilarity
# dbscan             CBLOF                  2.0
#                    LDCOF                  2.0
#                    naive                  2.0
#                    uCBLOF                 2.0
# kmeans             CBLOF                  NaN
#                    LDCOF                  NaN
#                    naive                  NaN
#                    uCBLOF                 NaN
