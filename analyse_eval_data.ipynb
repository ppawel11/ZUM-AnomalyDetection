# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_eval_data.csv")

# %%
sns.boxplot(df, x="algorithm", y="fscore")
plt.title(f"F-score on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="fscore", hue="grouping_algorithm")
plt.title(f"F-score on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="precision", hue="grouping_algorithm")
plt.title(f"precision on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="accuracy", hue="grouping_algorithm")
plt.title(f"accuracy on wine")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="recall", hue="grouping_algorithm")
plt.title(f"recall on wine")
plt.show()

# %%
df[df["anomaly_drop_rates"] == 0.3].groupby("algorithm").max("fscore")
# Out:
#                   Unnamed: 0    fscore  precision  accuracy    recall  \
# algorithm
# clustering               353  0.864865   1.000000  0.937888  0.761905
# isolation_forest         363  0.222222   0.400000  0.714286  0.153846
# one_class_svm            360  0.419355   0.265306  0.265306  1.000000
#
#                   anomalies_percentage  anomaly_drop_rates  n_clusters   eps  \
# algorithm
# clustering                         0.2                 0.3         6.0  15.0
# isolation_forest                   NaN                 0.3         NaN   NaN
# one_class_svm                      NaN                 0.3         NaN   NaN
#
#                   min_samples
# algorithm
# clustering                3.0
# isolation_forest          NaN
# one_class_svm             NaN

# %%
df[df["anomaly_drop_rates"] == 0.3].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 263  0.837838      1.000  0.925466
#                    LDCOF                 353  0.864865      1.000  0.937888
#                    naive                  83  0.837838      1.000  0.925466
#                    uCBLOF                173  0.837838      1.000  0.925466
# kmeans             CBLOF                 209  0.432432      0.875  0.776398
#                    LDCOF                 299  0.517241      1.000  0.826087
#                    naive                  29  0.513514      0.875  0.788820
#                    uCBLOF                119  0.567568      1.000  0.813665
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.738095                   0.2
#                    LDCOF          0.761905                   0.2
# ...

# %%
df[df["anomaly_drop_rates"] == 0.5].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 266  0.881356   1.000000  0.953020
#                    LDCOF                 356  0.847458   1.000000  0.939597
#                    naive                  86  0.847458   1.000000  0.939597
#                    uCBLOF                176  0.847458   1.000000  0.939597
# kmeans             CBLOF                 212  0.545455   1.000000  0.865772
#                    LDCOF                 302  0.590909   1.000000  0.879195
#                    naive                  32  0.542373   0.857143  0.838926
#                    uCBLOF                122  0.636364   1.000000  0.892617
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.866667                   0.2
#                    LDCOF          0.833333                   0.2
# ...

# %%
df[df["anomaly_drop_rates"] == 0.8].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 269  0.720000        1.0  0.954198
#                    LDCOF                 359  0.800000        1.0  0.961832
#                    naive                  89  0.960000        1.0  0.992366
#                    uCBLOF                179  0.880000        1.0  0.977099
# kmeans             CBLOF                 215  0.333333        0.5  0.908397
#                    LDCOF                 305  0.960000        1.0  0.992366
#                    naive                  35  0.666667        1.0  0.954198
#                    uCBLOF                125  0.800000        1.0  0.961832
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.916667                   0.2
#                    LDCOF          1.000000                   0.2
# ...

# %%
df = pd.read_csv("breast_cancer_eval_data.csv")

# %%
sns.boxplot(df, x="dissimilarity", y="fscore", hue="grouping_algorithm")
plt.title(f"F-score on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="precision", hue="grouping_algorithm")
plt.title(f"precision on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="accuracy", hue="grouping_algorithm")
plt.title(f"accuracy on breast cancer")
plt.show()

# %%
sns.boxplot(df, x="dissimilarity", y="recall", hue="grouping_algorithm")
plt.title(f"recall on breast cancer")
plt.show()

# %%
df[df["anomaly_drop_rates"] == 0.3].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 155  0.806897   1.000000  0.908497
#                    LDCOF                 209  0.806897   1.000000  0.908497
#                    naive                  47  0.813793   1.000000  0.911765
#                    uCBLOF                101  0.806897   1.000000  0.908497
# kmeans             CBLOF                 137  0.531034   0.766667  0.777778
#                    LDCOF                 191  0.806897   1.000000  0.908497
#                    naive                  29  0.793103   0.950820  0.901961
#                    uCBLOF                 83  0.806897   1.000000  0.908497
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.696429                   0.2
#                    LDCOF          0.696429                   0.2
# ...

# %%
df[df["anomaly_drop_rates"] == 0.5].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 158  0.862069   1.000000  0.943262
#                    LDCOF                 212  0.870690   1.000000  0.946809
#                    naive                  50  0.887931   1.000000  0.953901
#                    uCBLOF                104  0.887931   1.000000  0.953901
# kmeans             CBLOF                 140  0.543103   0.750000  0.812057
#                    LDCOF                 194  0.870690   1.000000  0.946809
#                    naive                  32  0.853448   0.928571  0.939716
#                    uCBLOF                 86  0.879310   1.000000  0.950355
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.833333                   0.2
#                    LDCOF          0.841667                   0.2
# ...

# %%
df[df["anomaly_drop_rates"] == 0.8].groupby(["grouping_algorithm", "dissimilarity"]).max("fscore")
# Out:
#                                   Unnamed: 0    fscore  precision  accuracy  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF                 161  0.886598   0.877551  0.977642
#                    LDCOF                 215  0.845361   0.875000  0.969512
#                    naive                  53  0.824742   0.875000  0.965447
#                    uCBLOF                107  0.804124   0.916667  0.961382
# kmeans             CBLOF                 143  0.493151   0.583333  0.910569
#                    LDCOF                 197  0.845361   1.000000  0.969512
#                    naive                  35  0.804124   0.875000  0.961382
#                    uCBLOF                 89  0.824742   0.916667  0.965447
#
#                                     recall  anomalies_percentage  \
# grouping_algorithm dissimilarity
# dbscan             CBLOF          0.979167                   0.2
#                    LDCOF          0.979167                   0.2
# ...
